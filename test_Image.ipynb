# %%
# 画像読み込み
import cv2
import numpy as np
import matplotlib.pyplot as plt

# 画像読み込み
# 保存ディレクトリと名前を入力
dir = r"E:\\Deeplearning\\C11800\\High\\N2N\\noise\\Denoise\\"
filename = r"1_noise_Standard.tif"
#グレー画像（16bit uint16）の読み込み
img = cv2.imread(dir + filename, cv2.IMREAD_UNCHANGED)

# 画像の表示：グレー画像
plt.imshow(img, cmap='gray')
plt.show()


# 画像のサイズを取得
h, w = img.shape
print("width: ", w)
print("height: ", h)
# Out:
# width:  128
# height:  128
